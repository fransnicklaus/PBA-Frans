# %% [markdown]
# #POS (part-of-speech)
# WEEK 5 PBA/ Irmasari Hafidz
# Date: 24/ Sept/ 2024
#
# Part-of-speech (POS) tagging is the process of assigning a part-of-speech tag (Noun, Verb, Adjective...) to each word in an input text.
#
# Reference:
# * https://github.com/jalajthanaki/POS-tag-workshop/blob/master/Introduction_to_POS.ipynb
# * (ipynb) dari NLP Specialization on Coursera by deeplearning.ai
# * More advanced POS tagger with Transformers (BERT) https://github.com/soutsios/pos-tagger-bert/blob/master/pos_tagger_bert.ipynb

# %% [markdown]
# ##Data Scrapping
# Data scrapping menggunakan BeautifulSoup dari 3 link berita, search keyword: CNN BPJS TBC
#
# Link:
#
# * link 1: https://news.detik.com/berita/d-7477855/program-jkn-bantu-mega-keluarga-dapat-akses-layanan-kesehatan-gratis
#
# * link 2: https://www.cnnindonesia.com/ekonomi/20230828195349-92-991552/uang-bpjs-terkuras-rp10-t-imbas-penyakit-napas-termasuk-dampak-polusi
#
# * link 3: https://www.cnnindonesia.com/ekonomi/20210715134614-83-668092/jalan-kesembuhan-habudin-lawan-tbc-bersama-jkn-kis

# %%
# !pip install beautifulsoup4 requests
# Out:
# Requirement already satisfied: beautifulsoup4 in d:\PBA\.venv\Lib\site-packages (4.14.3)
# Requirement already satisfied: requests in d:\PBA\.venv\Lib\site-packages (2.32.5)
# Requirement already satisfied: soupsieve>=1.6.1 in d:\PBA\.venv\Lib\site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\PBA\.venv\Lib\site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\PBA\.venv\Lib\site-packages (from requests) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in d:\PBA\.venv\Lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\PBA\.venv\Lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\PBA\.venv\Lib\site-packages (from requests) (2026.2.25)

# %%
# Install necessary libraries (if not already installed)
# !pip install beautifulsoup4 requests pandas

import requests
from bs4 import BeautifulSoup
import pandas as pd

# List of URLs to scrape
# urls = [
#     "https://news.detik.com/berita/d-7477855/program-jkn-bantu-mega-keluarga-dapat-akses-layanan-kesehatan-gratis",
#     "https://www.cnnindonesia.com/ekonomi/20230828195349-92-991552/uang-bpjs-terkuras-rp10-t-imbas-penyakit-napas-termasuk-dampak-polusi",
#     "https://www.cnnindonesia.com/ekonomi/20210715134614-83-668092/jalan-kesembuhan-habudin-lawan-tbc-bersama-jkn-kis"
# ]

urls = [
    "https://www.merahputih.com/post/read/hoaks-atau-fakta-terima-masukan-rakyat-prabowo-hentikan-program-makan-bergizi-gratis-ganti-dengan-bantuan-uang-tunai",
    "https://www.tribratakutim.com/berita-terkini/polri-melalui-polres-mempawah-meluncurkan-program-makan-bergizi-gratis/195580.html",
    "https://buleleng.bulelengkab.go.id/informasi/detail/berita/92_camat-buleleng-hadiri-grand-launching-program-mbg-di-sma-n-2-singaraja"
]

# Function to scrape content from a URL
def scrape_content(url):
    try:
        response = requests.get(url)
        if response.status_code == 200:
            soup = BeautifulSoup(response.content, 'html.parser')

            # Extract the title of the article
            title = soup.find('title').text

            # Extract the article's content
            paragraphs = soup.find_all('p')
            content = "\n".join([para.text for para in paragraphs])

            return {
                "url": url,
                "title": title,
                "content": content
            }
        else:
            return {
                "url": url,
                "title": None,
                "content": None,
                "error": f"Failed to fetch page, status code: {response.status_code}"
            }
    except Exception as e:
        return {
            "url": url,
            "title": None,
            "content": None,
            "error": str(e)
        }

# Scrape each URL and store the results in a list of dictionaries
data = []
for url in urls:
    result = scrape_content(url)
    data.append(result)

# Create a pandas DataFrame from the list of dictionaries
df = pd.DataFrame(data)

# Display the DataFrame
df.head()

# Save the DataFrame to a CSV file (optional)
df.to_csv('scraped_articles.csv', index=False)
# Out:
# Requirement already satisfied: beautifulsoup4 in d:\PBA\.venv\Lib\site-packages (4.14.3)
# Requirement already satisfied: requests in d:\PBA\.venv\Lib\site-packages (2.32.5)
# Requirement already satisfied: pandas in d:\PBA\.venv\Lib\site-packages (3.0.1)
# Requirement already satisfied: soupsieve>=1.6.1 in d:\PBA\.venv\Lib\site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in d:\PBA\.venv\Lib\site-packages (from beautifulsoup4) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\PBA\.venv\Lib\site-packages (from requests) (3.4.5)
# Requirement already satisfied: idna<4,>=2.5 in d:\PBA\.venv\Lib\site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\PBA\.venv\Lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in d:\PBA\.venv\Lib\site-packages (from requests) (2026.2.25)
# Requirement already satisfied: numpy>=1.26.0 in d:\PBA\.venv\Lib\site-packages (from pandas) (2.4.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\PBA\.venv\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in d:\PBA\.venv\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in d:\PBA\.venv\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# ## Data Definition
# Dataset adalah 3 link dengan kolom berisi: url, judul, konten.

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.merahputih.com/post/read/hoaks-ata...
# 1  https://www.tribratakutim.com/berita-terkini/p...
# 2  https://buleleng.bulelengkab.go.id/informasi/d...
#
#                                                title  \
# 0  [HOAKS atau FAKTA]: Terima Masukan Rakyat, Pra...
# 1  Polri melalui Polres Mempawah meluncurkan prog...
# 2  CAMAT BULELENG HADIRI GRAND LAUNCHING PROGRAM ...
#
#                                              content
# 0  © Copyright 2021 - merahputih.com\n \nMerahPut...
# 1   \n \nPolri melalui Polres Mempawah meluncurka...
# 2  Buleleng, Senin 6 April 2026 — Camat Buleleng,...

# %%
# Install and download NLTK resources for POS tagging
# !pip install nltk

import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# Requirement already satisfied: nltk in d:\PBA\.venv\Lib\site-packages (3.9.3)
# Requirement already satisfied: click in d:\PBA\.venv\Lib\site-packages (from nltk) (8.3.1)
# Requirement already satisfied: joblib in d:\PBA\.venv\Lib\site-packages (from nltk) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in d:\PBA\.venv\Lib\site-packages (from nltk) (2026.2.28)
# Requirement already satisfied: tqdm in d:\PBA\.venv\Lib\site-packages (from nltk) (4.67.3)
# Requirement already satisfied: colorama in d:\PBA\.venv\Lib\site-packages (from click->nltk) (0.4.6)
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Frans\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\Frans\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
from nltk import word_tokenize, pos_tag

# %%
# Importing packages and loading in the data set
import pandas as pd
from collections import defaultdict
import math
import numpy as np

# %%
# POS tagging preview for each article row
for index, row in df.iterrows():
    tokens = word_tokenize(str(row['content']))
    tags = pos_tag(tokens)
    print(f"Row {index}: {tags[:8]}\n")
# Out:
# Row 0: [('©', 'RB'), ('Copyright', 'NNP'), ('2021', 'CD'), ('-', ':'), ('merahputih.com', 'NN'), ('MerahPutih.com', 'NNP'), ('-', ':'), ('Presiden', 'NNP')]
#
# Row 1: [('Polri', 'NNP'), ('melalui', 'NN'), ('Polres', 'NNP'), ('Mempawah', 'NNP'), ('meluncurkan', 'JJ'), ('program', 'NN'), ('Makan', 'NNP'), ('Bergizi', 'NNP')]
#
# Row 2: [('Buleleng', 'NNP'), (',', ','), ('Senin', 'NNP'), ('6', 'CD'), ('April', 'NNP'), ('2026', 'CD'), ('—', 'NNP'), ('Camat', 'NNP')]

# %% [markdown]
# ## POS tag contoh 1st row data
# Diambil dari df dari kolom [content] baris ke [1]

# %%
df_content1 = df['content'][1]
df_content1
# Out:
# ' \n\xa0\nPolri melalui Polres Mempawah meluncurkan program Makan Bergizi Gratis (MBG) melalui Satuan Pelayanan Pemenuhan Gizi (SPPG) dengan pendistribusian makanan sehat kepada para siswa di sejumlah sekolah. Peluncuran perdana berlangsung di TK Kemala Bhayangkari 02 Mempawah Hilir dan disambut antusias ratusan siswa yang sejak pagi telah menunggu kedatangan tim MBG.\n\xa0\nProgram ini didukung operasional dapur MBG yang berfungsi sebagai pusat penyediaan makanan bergizi bagi para pelajar di wilayah tersebut. Para siswa mengikuti prosedur dengan mencuci tangan serta berdoa bersama sebelum menikmati makanan yang disediakan. Program MBG ini menjadi bagian dari komitmen Polri dalam mendukung pemenuhan gizi anak serta meningkatkan kualitas kesehatan generasi muda.\nPolres Kutai Timur\nJln. Bhayangkara No 1 Bukit Pelangi Kec. Sangatta Utara Kab.Kutai Timur | Telp: 082247809110\n© 2024 Tribratakutim.com | All Rights Reserved | Manage by Sobat Digital'

# %%
df_content1_tokens = word_tokenize(df_content1)
df_content1_tokens[:50]
# Out:
# ['Polri',
#  'melalui',
#  'Polres',
#  'Mempawah',
#  'meluncurkan',
#  'program',
#  'Makan',
#  'Bergizi',
#  'Gratis',
#  '(',
#  'MBG',
#  ')',
#  'melalui',
#  'Satuan',
#  'Pelayanan',
#  'Pemenuhan',
#  'Gizi',
#  '(',
#  'SPPG',
#  ')',
#  'dengan',
#  'pendistribusian',
#  'makanan',
#  'sehat',
#  'kepada',
#  'para',
#  'siswa',
#  'di',
#  'sejumlah',
#  'sekolah',
#  '.',
#  'Peluncuran',
#  'perdana',
#  'berlangsung',
#  'di',
#  'TK',
#  'Kemala',
#  'Bhayangkari',
#  '02',
#  'Mempawah',
#  'Hilir',
#  'dan',
#  'disambut',
#  'antusias',
#  'ratusan',
#  'siswa',
#  'yang',
#  'sejak',
#  'pagi',
#  'telah']

# %%
# NLTK models already downloaded in setup cell above

# %%
df_content1_pos = pos_tag(df_content1_tokens)

print("{:<16}{}".format("Word", "POS Tag") + "\n" + "-" * 30)
for word, tag in df_content1_pos:
    print("{:<16}{:>2}".format(word, tag))
# Out:
# Word            POS Tag
# ------------------------------
# Polri           NNP
# melalui         NN
# Polres          NNP
# Mempawah        NNP
# meluncurkan     JJ
# program         NN
# Makan           NNP
# Bergizi         NNP
# Gratis          NNP
# (                (
# MBG             NNP
# )                )
# melalui         VBP
# Satuan          JJ
# Pelayanan       NNP
# Pemenuhan       NNP
# Gizi            NNP
# (                (
# SPPG            NNP
# )                )
# dengan          VBZ
# pendistribusian JJ
# makanan         NN
# sehat           WP
# kepada          VBZ
# para            NN
# siswa           NN
# di              NN
# sejumlah        NN
# sekolah         NN
# .                .
# Peluncuran      NNP
# perdana         NN
# berlangsung     NN
# di              NN
# TK              NNP
# Kemala          NNP
# Bhayangkari     NNP
# 02              CD
# Mempawah        NNP
# Hilir           NNP
# dan             NN
# disambut        NN
# antusias        VBZ
# ratusan         JJ
# siswa           NN
# yang            NN
# sejak           NN
# pagi            NN
# telah           NN
# menunggu        NN
# kedatangan      VBD
# tim             JJ
# MBG             NNP
# .                .
# Program         NNP
# ini             NN
# didukung        NN
# operasional     JJ
# dapur           NN
# MBG             NNP
# yang            NNP
# berfungsi       VBD
# sebagai         JJ
# pusat           NN
# penyediaan      NN
# makanan         NN
# bergizi         NN
# bagi            NN
# para            NN
# pelajar         NN
# di              NN
# wilayah         NN
# tersebut        NN
# .                .
# Para            NNP
# siswa           VBD
# mengikuti       JJ
# prosedur        NN
# dengan          NN
# mencuci         FW
# tangan          JJ
# serta           NN
# berdoa          NN
# bersama         NN
# sebelum         NN
# menikmati       NN
# makanan         NN
# yang            NN
# disediakan      NN
# .                .
# Program         NNP
# MBG             NNP
# ini             VBZ
# menjadi         NN
# bagian          JJ
# dari            NN
# komitmen        NNS
# Polri           NNP
# dalam           NN
# mendukung       NN
# pemenuhan       NN
# gizi            NN
# anak            NN
# serta           NN
# meningkatkan    NN
# kualitas        NNS
# kesehatan       VBP
# generasi        JJ
# muda            NN
# .                .
# Polres          VBZ
# Kutai           NNP
# Timur           NNP
# Jln             NNP
# .                .
# Bhayangkara     NNP
# No              NNP
# 1               CD
# Bukit           NNP
# Pelangi         NNP
# Kec             NNP
# .                .
# Sangatta        NNP
# Utara           NNP
# Kab.Kutai       NNP
# Timur           NNP
# |               NNP
# Telp            NNP
# :                :
# 082247809110    CD
# ©               NN
# 2024            CD
# Tribratakutim.comNNP
# |               NNP
# All             NNP
# Rights          NNP
# Reserved        NNP
# |               NNP
# Manage          NNP
# by              IN
# Sobat           NNP
# Digital         NNP

# %% [markdown]
# ## Latihan 1
# Kerjakan POS tag untuk baris ke-2 dan ke-3.

# %%
import numpy as np
import pandas as pd

# %%
df_content1_pos
# Out:
# [('Polri', 'NNP'),
#  ('melalui', 'NN'),
#  ('Polres', 'NNP'),
#  ('Mempawah', 'NNP'),
#  ('meluncurkan', 'JJ'),
#  ('program', 'NN'),
#  ('Makan', 'NNP'),
#  ('Bergizi', 'NNP'),
#  ('Gratis', 'NNP'),
#  ('(', '('),
#  ('MBG', 'NNP'),
#  (')', ')'),
#  ('melalui', 'VBP'),
#  ('Satuan', 'JJ'),
#  ('Pelayanan', 'NNP'),
#  ('Pemenuhan', 'NNP'),
#  ('Gizi', 'NNP'),
#  ('(', '('),
#  ('SPPG', 'NNP'),
#  (')', ')'),
#  ('dengan', 'VBZ'),
#  ('pendistribusian', 'JJ'),
#  ('makanan', 'NN'),
#  ('sehat', 'WP'),
#  ('kepada', 'VBZ'),
#  ('para', 'NN'),
#  ('siswa', 'NN'),
#  ('di', 'NN'),
#  ('sejumlah', 'NN'),
#  ('sekolah', 'NN'),
#  ('.', '.'),
#  ('Peluncuran', 'NNP'),
#  ('perdana', 'NN'),
#  ('berlangsung', 'NN'),
#  ('di', 'NN'),
#  ('TK', 'NNP'),
#  ('Kemala', 'NNP'),
#  ('Bhayangkari', 'NNP'),
#  ('02', 'CD'),
#  ('Mempawah', 'NNP'),
#  ('Hilir', 'NNP'),
#  ('dan', 'NN'),
#  ('disambut', 'NN'),
#  ('antusias', 'VBZ'),
#  ('ratusan', 'JJ'),
#  ('siswa', 'NN'),
#  ('yang', 'NN'),
#  ('sejak', 'NN'),
#  ('pagi', 'NN'),
#  ('telah', 'NN'),
#  ('menunggu', 'NN'),
#  ('kedatangan', 'VBD'),
#  ('tim', 'JJ'),
#  ('MBG', 'NNP'),
#  ('.', '.'),
#  ('Program', 'NNP'),
#  ('ini', 'NN'),
#  ('didukung', 'NN'),
#  ('operasional', 'JJ'),
#  ('dapur', 'NN'),
#  ('MBG', 'NNP'),
#  ('yang', 'NNP'),
#  ('berfungsi', 'VBD'),
#  ('sebagai', 'JJ'),
#  ('pusat', 'NN'),
#  ('penyediaan', 'NN'),
#  ('makanan', 'NN'),
#  ('bergizi', 'NN'),
#  ('bagi', 'NN'),
#  ('para', 'NN'),
#  ('pelajar', 'NN'),
#  ('di', 'NN'),
#  ('wilayah', 'NN'),
#  ('tersebut', 'NN'),
#  ('.', '.'),
#  ('Para', 'NNP'),
#  ('siswa', 'VBD'),
#  ('mengikuti', 'JJ'),
#  ('prosedur', 'NN'),
#  ('dengan', 'NN'),
#  ('mencuci', 'FW'),
#  ('tangan', 'JJ'),
#  ('serta', 'NN'),
#  ('berdoa', 'NN'),
#  ('bersama', 'NN'),
#  ('sebelum', 'NN'),
#  ('menikmati', 'NN'),
#  ('makanan', 'NN'),
#  ('yang', 'NN'),
#  ('disediakan', 'NN'),
#  ('.', '.'),
#  ('Program', 'NNP'),
#  ('MBG', 'NNP'),
#  ('ini', 'VBZ'),
#  ('menjadi', 'NN'),
#  ('bagian', 'JJ'),
#  ('dari', 'NN'),
#  ('komitmen', 'NNS'),
#  ('Polri', 'NNP'),
#  ('dalam', 'NN'),
#  ('mendukung', 'NN'),
#  ('pemenuhan', 'NN'),
#  ('gizi', 'NN'),
#  ('anak', 'NN'),
#  ('serta', 'NN'),
#  ('meningkatkan', 'NN'),
#  ('kualitas', 'NNS'),
#  ('kesehatan', 'VBP'),
#  ('generasi', 'JJ'),
#  ('muda', 'NN'),
#  ('.', '.'),
#  ('Polres', 'VBZ'),
#  ('Kutai', 'NNP'),
#  ('Timur', 'NNP'),
#  ('Jln', 'NNP'),
#  ('.', '.'),
#  ('Bhayangkara', 'NNP'),
#  ('No', 'NNP'),
#  ('1', 'CD'),
#  ('Bukit', 'NNP'),
#  ('Pelangi', 'NNP'),
#  ('Kec', 'NNP'),
#  ('.', '.'),
#  ('Sangatta', 'NNP'),
#  ('Utara', 'NNP'),
#  ('Kab.Kutai', 'NNP'),
#  ('Timur', 'NNP'),
#  ('|', 'NNP'),
#  ('Telp', 'NNP'),
#  (':', ':'),
#  ('082247809110', 'CD'),
#  ('©', 'NN'),
#  ('2024', 'CD'),
#  ('Tribratakutim.com', 'NNP'),
#  ('|', 'NNP'),
#  ('All', 'NNP'),
#  ('Rights', 'NNP'),
#  ('Reserved', 'NNP'),
#  ('|', 'NNP'),
#  ('Manage', 'NNP'),
#  ('by', 'IN'),
#  ('Sobat', 'NNP'),
#  ('Digital', 'NNP')]

# %%
import pandas as pd

# In NLTK flow, df_content1_pos is already a list of (word, pos_tag) tuples.
# Create a list of dictionaries to store each word and its POS tag.
word_pos_list = [{"Word": word, "POS Tag": tag} for word, tag in df_content1_pos]

# Convert the list of dictionaries to a pandas DataFrame
df_word_pos = pd.DataFrame(word_pos_list)

# Display the DataFrame
print(df_word_pos)

# Optionally, save the DataFrame to a CSV file
df_word_pos.to_csv("word_pos_tags.csv", index=False)
# Out:
#             Word POS Tag
# 0          Polri     NNP
# 1        melalui      NN
# 2         Polres     NNP
# 3       Mempawah     NNP
# 4    meluncurkan      JJ
# ..           ...     ...
# 138            |     NNP
# 139       Manage     NNP
# 140           by      IN
# 141        Sobat     NNP
# 142      Digital     NNP
#
# [143 rows x 2 columns]

# %%
import pandas as pd
from collections import Counter

# In NLTK flow, df_content1_pos is already a list of (word, pos_tag) tuples.
# Create a list of dictionaries to store each word and its POS tag.
word_pos_list = [{"Word": word, "POS Tag": tag} for word, tag in df_content1_pos]

# Convert the list of dictionaries to a pandas DataFrame
df_word_pos = pd.DataFrame(word_pos_list)

# Count the occurrences of each POS tag
tag_counts = df_word_pos['POS Tag'].value_counts()

# Get the number of unique words for each POS tag
unique_tokens_per_tag = df_word_pos.groupby('POS Tag')['Word'].nunique()

# Combine the counts and unique tokens into a summary DataFrame
summary_df = pd.DataFrame({
    'Tag': tag_counts.index,
    'Count': tag_counts.values,
    'Unique Tokens': unique_tokens_per_tag
}).reset_index(drop=True)

# Sort by count in descending order
summary_df = summary_df.sort_values(by='Count', ascending=False)

# Display the summary DataFrame
print(summary_df)

# Optionally, save the summary DataFrame to a CSV file
summary_df.to_csv("pos_tags_summary.csv", index=False)
# Out:
#     Tag  Count  Unique Tokens
# 0    NN     53              1
# 1   NNP     48              1
# 2    JJ     11              1
# 3     .      7              1
# 4   VBZ      5              4
# 5    CD      4              1
# 6   VBD      3              1
# 7     (      2             11
# 8     )      2             45
# 9   VBP      2             39
# 10  NNS      2              2
# 11   WP      1              3
# 12   FW      1              2
# 13    :      1              5
# 14   IN      1              1

# %%
# Calculate the sum of the 'Count' column
total_count = summary_df['Count'].sum()

# Display the result
print("Total Count:", total_count)
# Out:
# Total Count: 143
